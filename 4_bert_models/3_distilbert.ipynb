# %% [markdown]
# # Finetune DistilBERT
#
# Notebook by Jenna Sparks

# %%
# !pip install -q codecarbon

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.11)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.27.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
# !pip install transformers datasets codecarbon
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.47.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.2.0)
# Requirement already satisfied: codecarbon in /usr/local/lib/python3.11/dist-packages (2.8.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.27.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.11)
# Requirement already satisfied: arrow in /usr/local/lib/python3.11/dist-packages (from codecarbon) (1.3.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from codecarbon) (8.1.8)
# Requirement already satisfied: fief-client[cli] in /usr/local/lib/python3.11/dist-packages (from codecarbon) (0.20.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from codecarbon) (0.21.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from codecarbon) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from codecarbon) (9.0.0)
# Requirement already satisfied: pynvml in /usr/local/lib/python3.11/dist-packages (from codecarbon) (12.0.0)
# Requirement already satisfied: questionary in /usr/local/lib/python3.11/dist-packages (from codecarbon) (2.1.0)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.11/dist-packages (from codecarbon) (3.11.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from codecarbon) (13.9.4)
# Requirement already satisfied: typer in /usr/local/lib/python3.11/dist-packages (from codecarbon) (0.15.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.11/dist-packages (from arrow->codecarbon) (2.8.2)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /usr/local/lib/python3.11/dist-packages (from arrow->codecarbon) (2.9.0.20241206)
# Requirement already satisfied: httpx<0.28.0,>=0.21.3 in /usr/local/lib/python3.11/dist-packages (from fief-client[cli]->codecarbon) (0.27.2)
# Requirement already satisfied: jwcrypto<2.0.0,>=1.4 in /usr/local/lib/python3.11/dist-packages (from fief-client[cli]->codecarbon) (1.5.6)
# Requirement already satisfied: yaspin in /usr/local/lib/python3.11/dist-packages (from fief-client[cli]->codecarbon) (3.1.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: nvidia-ml-py<13.0.0a0,>=12.0.0 in /usr/local/lib/python3.11/dist-packages (from pynvml->codecarbon) (12.570.86)
# Requirement already satisfied: prompt_toolkit<4.0,>=2.0 in /usr/local/lib/python3.11/dist-packages (from questionary->codecarbon) (3.0.50)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->codecarbon) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->codecarbon) (2.18.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer->codecarbon) (1.5.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (1.0.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon) (0.14.0)
# Requirement already satisfied: cryptography>=3.4 in /usr/local/lib/python3.11/dist-packages (from jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (43.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->codecarbon) (0.1.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt_toolkit<4.0,>=2.0->questionary->codecarbon) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7.0->arrow->codecarbon) (1.17.0)
# Requirement already satisfied: termcolor<2.4.0,>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from yaspin->fief-client[cli]->codecarbon) (2.3.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=3.4->jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=3.4->jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon) (2.22)

# %%
# !pip install peft
# Out:
# Requirement already satisfied: peft in /usr/local/lib/python3.11/dist-packages (0.14.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from peft) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from peft) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from peft) (6.0.2)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from peft) (2.5.1+cu124)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (from peft) (4.47.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from peft) (4.67.1)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from peft) (1.2.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from peft) (0.5.2)
# Requirement already satisfied: huggingface-hub>=0.25.0 in /usr/local/lib/python3.11/dist-packages (from peft) (0.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.25.0->peft) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.25.0->peft) (2024.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.25.0->peft) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.25.0->peft) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers->peft) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers->peft) (0.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.13.0->peft) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.25.0->peft) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.25.0->peft) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.25.0->peft) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.25.0->peft) (2024.12.14)

# %%
# Standard libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Carbon and eval libraries
from codecarbon import EmissionsTracker
import random
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, roc_auc_score
from datetime import datetime

# ML libraries
from transformers import DistilBertForSequenceClassification, DistilBertTokenizer, TrainingArguments, Trainer
from datasets import load_dataset, Dataset

import torch
from torch.utils.data import DataLoader

# Incorporating LoRA
from peft import get_peft_model, LoraConfig, TaskType

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
model = DistilBertForSequenceClassification.from_pretrained('distilbert-base-uncased', num_labels=8)
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')

# Define LoRA config
lora_config = LoraConfig(
    r=16,
    lora_alpha=32,
    target_modules=["q_lin", "k_lin", "v_lin", "out_lin"],  # Target specific Linear layers within attention
    lora_dropout=0.05,
    bias="none",
)

# Apply LoRA to model
model = get_peft_model(model, lora_config)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# # Freeze some layers

# %%
for param in model.distilbert.embeddings.parameters():
    param.requires_grad = False

for layer in model.distilbert.transformer.layer[:4]:  # Freeze first 4 layers
    for param in layer.parameters():
        param.requires_grad = False

# %% [markdown]
# # Load data

# %%
folder = '/content/drive/My Drive/Juliana/'

# load X_train, X_test, y_train, y_test from folder
X_train = pd.read_csv(folder + 'X_train.csv')
X_test = pd.read_csv(folder + 'X_test.csv')
y_train = pd.read_csv(folder + 'y_train.csv')
y_test = pd.read_csv(folder + 'y_test.csv')

# %%
# Combine features and labels
train_df = pd.concat([X_train, y_train], axis=1)
test_df = pd.concat([X_test, y_test], axis=1)

# Define the LABEL_MAPPING dictionary
LABEL_MAPPING = {
    "0_not_relevant": 0,
    "1_not_happening": 1,
    "2_not_human": 2,
    "3_not_bad": 3,
    "4_solutions_harmful_unnecessary": 4,
    "5_science_unreliable": 5,
    "6_proponents_biased": 6,
    "7_fossil_fuels_needed": 7
}

# Apply LABEL_MAPPING to the 'label' column in both train_df and test_df
train_df['label'] = train_df['label'].map(LABEL_MAPPING)
test_df['label'] = test_df['label'].map(LABEL_MAPPING)

# Convert to Hugging Face datasets
train_dataset = Dataset.from_pandas(train_df)
test_dataset = Dataset.from_pandas(test_df)

# Combine into a single dataset dictionary
dataset = {
    'train': train_dataset,
    'test': test_dataset
}

# %%
def tokenize_function(examples):
    return tokenizer(examples['quote'], padding='max_length', truncation=True)

tokenized_datasets = train_dataset.map(tokenize_function, batched=True)
# Out:
# Map:   0%|          | 0/3599 [00:00<?, ? examples/s]

# %%
tokenized_test_datasets = dataset['test'].map(tokenize_function, batched=True)
# Out:
# Map:   0%|          | 0/945 [00:00<?, ? examples/s]

# %%
# training_args = TrainingArguments(
#     output_dir='./results',
#     num_train_epochs=3,
#     per_device_train_batch_size=16,
#     per_device_eval_batch_size=64,
#     warmup_steps=500,
#     weight_decay=0.01,
#     logging_dir='./logs',
# )

# %%
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=3,
    per_device_train_batch_size=32,  # Increased from 16
    per_device_eval_batch_size=64,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir='./logs',
    learning_rate=5e-5,  # Added learning rate
    lr_scheduler_type="linear",  # Added learning rate scheduler type
    evaluation_strategy="epoch",  # Evaluate at the end of each epoch
    save_strategy="epoch",  # Save at the end of each epoch
    load_best_model_at_end=True,  # Load the best model when finished training (in terms of evaluation metrics)
    metric_for_best_model="accuracy",  # Use accuracy to determine the best model
)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
trainer = Trainer(
    model=model,                         # The instantiated 🤗 Transformers model to be trained
    args=training_args,                  # Training arguments, defined above
    train_dataset=tokenized_datasets,    # Training dataset
    eval_dataset=tokenized_test_datasets # Evaluation dataset
)

trainer.train()
# Out:
# [codecarbon INFO @ 23:24:52] [setup] RAM Tracking...
# [codecarbon INFO @ 23:24:52] [setup] CPU Tracking...
# [codecarbon WARNING @ 23:24:52] No CPU tracking mode found. Falling back on CPU constant mode.
#  Linux OS detected: Please ensure RAPL files exist at \sys\class\powercap\intel-rapl to measure CPU
#
# [codecarbon WARNING @ 23:24:53] We saw that you have a Intel(R) Xeon(R) CPU @ 2.20GHz but we don't know it. Please contact us.
# [codecarbon INFO @ 23:24:53] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 23:24:53] [setup] GPU Tracking...
# [codecarbon INFO @ 23:24:53] No GPU found.
# [codecarbon INFO @ 23:24:53] >>> Tracker's metadata:
# [codecarbon INFO @ 23:24:53]   Platform system: Linux-6.1.85+-x86_64-with-glibc2.35
# [codecarbon INFO @ 23:24:53]   Python version: 3.11.11
# [codecarbon INFO @ 23:24:53]   CodeCarbon version: 2.8.3
# [codecarbon INFO @ 23:24:53]   Available RAM : 12.675 GB
# [codecarbon INFO @ 23:24:53]   CPU count: 2
# [codecarbon INFO @ 23:24:53]   CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 23:24:53]   GPU count: None
# [codecarbon INFO @ 23:24:53]   GPU model: None
# [codecarbon INFO @ 23:24:54] Saving emissions data to file /content/results/emissions.csv
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Currently logged in as: jenna_sparks (jenna_r_sparks). Use `wandb login --relogin` to force relogin
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Tracking run with wandb version 0.19.4
# Run data is saved locally in <code>/content/wandb/run-20250130_232455-pnu1nuk3</code>
# Syncing run <strong><a href='https://wandb.ai/jenna_r_sparks/huggingface/runs/pnu1nuk3' target="_blank">./results</a></strong> to <a href='https://wandb.ai/jenna_r_sparks/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/jenna_r_sparks/huggingface' target="_blank">https://wandb.ai/jenna_r_sparks/huggingface</a>
#  View run at <a href='https://wandb.ai/jenna_r_sparks/huggingface/runs/pnu1nuk3' target="_blank">https://wandb.ai/jenna_r_sparks/huggingface/runs/pnu1nuk3</a>
# [codecarbon INFO @ 23:25:12] Energy consumed for RAM : 0.000020 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:25:12] Energy consumed for all CPUs : 0.000177 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:25:12] 0.000197 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:25:27] Energy consumed for RAM : 0.000040 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:25:27] Energy consumed for all CPUs : 0.000354 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:25:27] 0.000394 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:25:42] Energy consumed for RAM : 0.000059 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:25:42] Energy consumed for all CPUs : 0.000531 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:25:42] 0.000590 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:25:57] Energy consumed for RAM : 0.000079 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:25:57] Energy consumed for all CPUs : 0.000708 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:25:57] 0.000787 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:26:12] Energy consumed for RAM : 0.000099 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:26:12] Energy consumed for all CPUs : 0.000885 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:26:12] 0.000984 kWh of electricity used since the beginning.
#     <div>
#
#       <progress value='114' max='339' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [114/339 2:21:48 < 4:44:52, 0.01 it/s, Epoch 1/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>No log</td>
#     </tr>
#   </tbody>
# </table><p>
# [codecarbon INFO @ 23:26:27] Energy consumed for RAM : 0.000119 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:26:27] Energy consumed for all CPUs : 0.001062 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:26:27] 0.001181 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:26:42] Energy consumed for RAM : 0.000139 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:26:42] Energy consumed for all CPUs : 0.001239 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:26:42] 0.001378 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:26:57] Energy consumed for RAM : 0.000158 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:26:57] Energy consumed for all CPUs : 0.001416 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:26:57] 0.001575 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:26:57] 0.003510 g.CO2eq/s mean an estimation of 110.69369988598176 kg.CO2eq/year
# [codecarbon INFO @ 23:27:12] Energy consumed for RAM : 0.000178 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:27:12] Energy consumed for all CPUs : 0.001593 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:27:12] 0.001771 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:27:27] Energy consumed for RAM : 0.000198 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:27:27] Energy consumed for all CPUs : 0.001770 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:27:27] 0.001968 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:27:42] Energy consumed for RAM : 0.000218 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:27:42] Energy consumed for all CPUs : 0.001948 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:27:42] 0.002165 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:27:57] Energy consumed for RAM : 0.000237 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:27:57] Energy consumed for all CPUs : 0.002125 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:27:57] 0.002362 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:28:12] Energy consumed for RAM : 0.000257 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:28:12] Energy consumed for all CPUs : 0.002302 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:28:12] 0.002559 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:28:27] Energy consumed for RAM : 0.000277 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:28:27] Energy consumed for all CPUs : 0.002479 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:28:27] 0.002756 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:28:42] Energy consumed for RAM : 0.000297 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:28:42] Energy consumed for all CPUs : 0.002655 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:28:42] 0.002952 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:28:57] Energy consumed for RAM : 0.000317 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:28:57] Energy consumed for all CPUs : 0.002833 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:28:57] 0.003149 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:28:57] 0.003511 g.CO2eq/s mean an estimation of 110.71418947154147 kg.CO2eq/year
# [codecarbon INFO @ 23:29:12] Energy consumed for RAM : 0.000336 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23
kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:46:42] Energy consumed for RAM : 0.001722 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:46:42] Energy consumed for all CPUs : 0.015404 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:46:42] 0.017126 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:46:57] Energy consumed for RAM : 0.001742 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:46:58] Energy consumed for all CPUs : 0.015581 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:46:58] 0.017323 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:46:58] 0.003509 g.CO2eq/s mean an estimation of 110.66916881730684 kg.CO2eq/year
# [codecarbon INFO @ 23:47:13] Energy consumed for RAM : 0.001762 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:47:13] Energy consumed for all CPUs : 0.015759 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:47:13] 0.017520 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:47:28] Energy consumed for RAM : 0.001781 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:47:28] Energy consumed for all CPUs : 0.015936 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:47:28] 0.017717 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:47:43] Energy consumed for RAM : 0.001801 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:47:43] Energy consumed for all CPUs : 0.016113 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:47:43] 0.017914 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:47:58] Energy consumed for RAM : 0.001821 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:47:58] Energy consumed for all CPUs : 0.016290 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:47:58] 0.018111 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:48:13] Energy consumed for RAM : 0.001841 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:48:13] Energy consumed for all CPUs : 0.016467 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:48:13] 0.018308 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:48:28] Energy consumed for RAM : 0.001861 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:48:28] Energy consumed for all CPUs : 0.016644 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:48:28] 0.018505 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:48:43] Energy consumed for RAM : 0.001880 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:48:43] Energy consumed for all CPUs : 0.016821 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:48:43] 0.018701 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:48:58] Energy consumed for RAM : 0.001900 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:48:58] Energy consumed for all CPUs : 0.016998 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:48:58] 0.018898 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:48:58] 0.003511 g.CO2eq/s mean an estimation of 110.71427311908788 kg.CO2eq/year
# [codecarbon INFO @ 23:49:13] Energy consumed for RAM : 0.001920 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:49:13] Energy consumed for all CPUs : 0.017175 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:49:13] 0.019095 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:49:28] Energy consumed for RAM : 0.001940 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:49:28] Energy consumed for all CPUs : 0.017352 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:49:28] 0.019292 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:49:43] Energy consumed for RAM : 0.001960 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:49:43] Energy consumed for all CPUs : 0.017529 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:49:43] 0.019489 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:49:58] Energy consumed for RAM : 0.001979 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:49:58] Energy consumed for all CPUs : 0.017707 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:49:58] 0.019686 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:50:13] Energy consumed for RAM : 0.001999 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:50:13] Energy consumed for all CPUs : 0.017884 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:50:13] 0.019883 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:50:28] Energy consumed for RAM : 0.002019 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:50:28] Energy consumed for all CPUs : 0.018061 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:50:28] 0.020080 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:50:43] Energy consumed for RAM : 0.002039 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:50:43] Energy consumed for all CPUs : 0.018238 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:50:43] 0.020277 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:50:58] Energy consumed for RAM : 0.002059 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:50:58] Energy consumed for all CPUs : 0.018415 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:50:58] 0.020474 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:50:58] 0.003511 g.CO2eq/s mean an estimation of 110.73249977503053 kg.CO2eq/year
# [codecarbon INFO @ 23:51:13] Energy consumed for RAM : 0.002078 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:51:13] Energy consumed for all CPUs : 0.018593 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:51:13] 0.020671 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:51:28] Energy consumed for RAM : 0.002098 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:51:28] Energy consumed for all CPUs : 0.018770 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:51:28] 0.020868 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:51:43] Energy consumed for RAM : 0.002118 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:51:43] Energy consumed for all CPUs : 0.018947 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:51:43] 0.021065 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:51:58] Energy consumed for RAM : 0.002138 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:51:58] Energy consumed for all CPUs : 0.019124 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:51:58] 0.021262 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:52:13] Energy consumed for RAM : 0.002158 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:52:13] Energy consumed for all CPUs : 0.019301 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:52:13] 0.021459 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:52:28] Energy consumed for RAM : 0.002177 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:52:28] Energy consumed for all CPUs : 0.019478 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:52:28] 0.021655 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:52:43] Energy consumed for RAM : 0.002197 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:52:43] Energy consumed for all CPUs : 0.019655 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:52:43] 0.021852 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:52:58] Energy consumed for RAM : 0.002217 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:52:58] Energy consumed for all CPUs : 0.019832 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:52:58] 0.022049 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:52:58] 0.003511 g.CO2eq/s mean an estimation of 110.72049424888696 kg.CO2eq/year
# [codecarbon INFO @ 23:53:13] Energy consumed for RAM : 0.002237 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:53:13] Energy consumed for all CPUs : 0.020009 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:53:13] 0.022246 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:53:28] Energy consumed for RAM : 0.002257 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:53:28] Energy consumed for all CPUs : 0.020186 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:53:28] 0.022443 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:53:43] Energy consumed for RAM : 0.002276 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:53:43] Energy consumed for all CPUs : 0.020363 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:53:43] 0.022640 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:53:58] Energy consumed for RAM : 0.002296 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:53:58] Energy consumed for all CPUs : 0.020541 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:53:58] 0.022837 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:54:13] Energy consumed for RAM : 0.002316 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:54:13] Energy consumed for all CPUs : 0.020717 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:54:13] 0.023033 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:54:28] Energy consumed for RAM : 0.002336 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:54:28] Energy consumed for all CPUs : 0.020894 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:54:28] 0.023230 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:54:43] Energy consumed for RAM : 0.002355 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:54:43] Energy consumed for all CPUs : 0.021071 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:54:43] 0.023427 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:54:58] Energy consumed for RAM : 0.002375 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:54:58] Energy consumed for all CPUs : 0.021248 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:54:58] 0.023623 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:54:58] 0.003511 g.CO2eq/s mean an estimation of 110.70820824184055 kg.CO2eq/year
# [codecarbon INFO @ 23:55:13] Energy consumed for RAM : 0.002395 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:55:13] Energy consumed for all CPUs : 0.021425 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:55:13] 0.023820 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:55:28] Energy consumed for RAM : 0.002415 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:55:28] Energy consumed for all CPUs : 0.021602 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:55:28] 0.024017 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:55:43] Energy consumed for RAM : 0.002435 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:55:43] Energy consumed for all CPUs : 0.021779 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:55:43] 0.024214 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:55:58] Energy consumed for RAM : 0.002454 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:55:58] Energy consumed for all CPUs : 0.021956 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:55:58] 0.024411 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:56:13] Energy consumed for RAM : 0.002474 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:56:13] Energy consumed for all CPUs : 0.022133 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:56:13] 0.024607 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:56:28] Energy consumed for RAM : 0.002494 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:56:28] Energy consumed for all CPUs : 0.022310 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:56:28] 0.024804 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:56:43] Energy consumed for RAM : 0.002514 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:56:43] Energy consumed for all CPUs : 0.022488 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:56:43] 0.025001 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:56:58] Energy consumed for RAM : 0.002534 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:56:58] Energy consumed for all CPUs : 0.022665 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:56:58] 0.025198 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:56:58] 0.003510 g.CO2eq/s mean an estimation of 110.70500591300717 kg.CO2eq/year
# [codecarbon INFO @ 23:57:13] Energy consumed for RAM : 0.002553 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:57:13] Energy consumed for all CPUs : 0.022842 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:57:13] 0.025395 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:57:28] Energy consumed for RAM : 0.002573 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:57:28] Energy consumed for all CPUs : 0.023019 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:57:28] 0.025592 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:57:43] Energy consumed for RAM : 0.002593 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:57:43] Energy consumed for all CPUs : 0.023196 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:57:43] 0.025789 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:57:58] Energy consumed for RAM : 0.002613 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:57:58] Energy consumed for all CPUs : 0.023373 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:57:58] 0.025986 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:58:13] Energy consumed for RAM : 0.002633 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:58:13] Energy consumed for all CPUs : 0.023551 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:58:13] 0.026183 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:58:28] Energy consumed for RAM : 0.002652 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:58:28] Energy consumed for all CPUs : 0.023728 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:58:28] 0.026380 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:58:43] Energy consumed for RAM : 0.002672 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:58:43] Energy consumed for all CPUs : 0.023905 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:58:43] 0.026578 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:58:58] Energy consumed for RAM : 0.002692 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:58:58] Energy consumed for all CPUs : 0.024082 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:58:58] 0.026775 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:58:58] 0.003511 g.CO2eq/s mean an estimation of 110.72056421298241 kg.CO2eq/year
# [codecarbon INFO @ 23:59:13] Energy consumed for RAM : 0.002712 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:59:13] Energy consumed for all CPUs : 0.024260 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:59:13] 0.026972 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:59:28] Energy consumed for RAM : 0.002732 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:59:28] Energy consumed for all CPUs : 0.024437 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:59:28] 0.027169 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:59:43] Energy consumed for RAM : 0.002752 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:59:43] Energy consumed for all CPUs : 0.024614 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:59:43] 0.027366 kWh of electricity used since the beginning.
# [codecarbon INFO @ 23:59:58] Energy consumed for RAM : 0.002771 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 23:59:58] Energy consumed for all CPUs : 0.024791 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 23:59:58] 0.027562 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:00:13] Energy consumed for RAM : 0.002791 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 00:00:13] Energy consumed for all CPUs : 0.024968 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 00:00:13] 0.027759 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:00:28] Energy consumed for RAM : 0.002811 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 00:00:28] Energy consumed for all CPUs : 0.025145 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 00:00:28] 0.027956 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:00:43] Energy consumed for RAM : 0.002831 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 00:00:43] Energy consumed for all CPUs : 0.025322 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 00:00:43] 0.028153 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:00:58] Energy consumed for RAM : 0.002851 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 00:00:58] Energy consumed for all CPUs : 0.025499 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 00:00:58] 0.028350 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:00:58] 0.003510 g.CO2eq/s mean an estimation of 110.70689112767225 kg.CO2eq/year
# [codecarbon INFO @ 00:01:13] Energy consumed for RAM : 0.002870 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 00:01:13] Energy consumed for all CPUs : 0.025676 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 00:01:13] 0.028546 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:01:28] Energy consumed for RAM : 0.002890 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 00:01:28] Energy consumed for all CPUs : 0.025853 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 00:01:28] 0.028743 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:01:43] Energy consumed for RAM : 0.002910 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 00:01:43] Energy consumed for all CPUs : 0.026030 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 00:01:43] 0.028940 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:01:58] Energy consumed for RAM : 0.002930 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 00:01:58] Energy consumed for all CPUs : 0.026207 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 00:01:58] 0.029137 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:02:13] Energy consumed for RAM : 0.002949 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 00:02:13] Energy consumed for all CPUs : 0.026384 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 00:02:13] 0.029334 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:02:28] Energy consumed for RAM : 0.002969 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 00:02:28] Energy consumed for all CPUs : 0.026562 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 00:02:28] 0.029531 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:02:43] Energy consumed for RAM : 0.002989 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 00:02:43] Energy consumed for all CPUs : 0.026739 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 00:02:43] 0.029728 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:02:58] Energy consumed for RAM : 0.003009 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 00:02:58] Energy consumed for all CPUs : 0.026916 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 00:02:58] 0.029924 kWh of electricity used since the beginning.
# [codecarbon INFO @ 00:02:58] 0.003510 g.CO2eq/s mean an estimation of 110.70504691516302 kg.CO2eq/year
# ...
# [codecarbon INFO @ 01:54:33] Energy consumed for RAM : 0.011838 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 01:54:33] Energy consumed for all CPUs : 0.105897 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:54:33] 0.117736 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:54:48] Energy consumed for RAM : 0.011858 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 01:54:48] Energy consumed for all CPUs : 0.106075 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:54:48] 0.117933 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:55:03] Energy consumed for RAM : 0.011878 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 01:55:03] Energy consumed for all CPUs : 0.106252 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:55:03] 0.118130 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:55:03] 0.003511 g.CO2eq/s mean an estimation of 110.71817803101082 kg.CO2eq/year
# [codecarbon INFO @ 01:55:18] Energy consumed for RAM : 0.011898 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 01:55:18] Energy consumed for all CPUs : 0.106429 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:55:18] 0.118326 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:55:33] Energy consumed for RAM : 0.011918 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 01:55:33] Energy consumed for all CPUs : 0.106606 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:55:33] 0.118523 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:55:48] Energy consumed for RAM : 0.011937 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 01:55:48] Energy consumed for all CPUs : 0.106783 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:55:48] 0.118721 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:56:03] Energy consumed for RAM : 0.011957 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 01:56:03] Energy consumed for all CPUs : 0.106960 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:56:03] 0.118917 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:56:18] Energy consumed for RAM : 0.011977 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 01:56:18] Energy consumed for all CPUs : 0.107137 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:56:18] 0.119114 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:56:33] Energy consumed for RAM : 0.011997 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 01:56:33] Energy consumed for all CPUs : 0.107314 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:56:33] 0.119311 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:56:48] Energy consumed for RAM : 0.012016 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 01:56:48] Energy consumed for all CPUs : 0.107489 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:56:48] 0.119505 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:57:03] Energy consumed for RAM : 0.012036 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 01:57:03] Energy consumed for all CPUs : 0.107666 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:57:03] 0.119702 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:57:03] 0.003505 g.CO2eq/s mean an estimation of 110.54669542233347 kg.CO2eq/year
# [codecarbon INFO @ 01:57:18] Energy consumed for RAM : 0.012056 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 01:57:18] Energy consumed for all CPUs : 0.107843 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:57:18] 0.119899 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:57:33] Energy consumed for RAM : 0.012076 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 01:57:33] Energy consumed for all CPUs : 0.108020 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:57:33] 0.120096 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:57:48] Energy consumed for RAM : 0.012096 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 01:57:48] Energy consumed for all CPUs : 0.108197 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:57:48] 0.120293 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:58:03] Energy consumed for RAM : 0.012115 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 01:58:03] Energy consumed for all CPUs : 0.108375 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:58:03] 0.120490 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:58:18] Energy consumed for RAM : 0.012135 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 01:58:18] Energy consumed for all CPUs : 0.108552 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:58:18] 0.120687 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:58:33] Energy consumed for RAM : 0.012155 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 01:58:33] Energy consumed for all CPUs : 0.108729 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:58:33] 0.120884 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:58:48] Energy consumed for RAM : 0.012175 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 01:58:48] Energy consumed for all CPUs : 0.108906 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:58:48] 0.121080 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:59:03] Energy consumed for RAM : 0.012195 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 01:59:03] Energy consumed for all CPUs : 0.109083 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:59:03] 0.121277 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:59:03] 0.003509 g.CO2eq/s mean an estimation of 110.670032371017 kg.CO2eq/year
# [codecarbon INFO @ 01:59:18] Energy consumed for RAM : 0.012214 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 01:59:18] Energy consumed for all CPUs : 0.109260 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:59:18] 0.121474 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:59:33] Energy consumed for RAM : 0.012234 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 01:59:33] Energy consumed for all CPUs : 0.109437 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:59:33] 0.121671 kWh of electricity used since the beginning.
# [codecarbon INFO @ 01:59:48] Energy consumed for RAM : 0.012254 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 01:59:48] Energy consumed for all CPUs : 0.109614 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 01:59:48] 0.121868 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:00:03] Energy consumed for RAM : 0.012274 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 02:00:03] Energy consumed for all CPUs : 0.109791 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 02:00:03] 0.122065 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:00:18] Energy consumed for RAM : 0.012294 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 02:00:18] Energy consumed for all CPUs : 0.109968 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 02:00:18] 0.122262 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:00:33] Energy consumed for RAM : 0.012313 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 02:00:33] Energy consumed for all CPUs : 0.110145 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 02:00:33] 0.122459 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:00:48] Energy consumed for RAM : 0.012333 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 02:00:48] Energy consumed for all CPUs : 0.110323 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 02:00:48] 0.122656 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:01:03] Energy consumed for RAM : 0.012353 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 02:01:03] Energy consumed for all CPUs : 0.110500 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 02:01:03] 0.122853 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:01:03] 0.003511 g.CO2eq/s mean an estimation of 110.70949906971894 kg.CO2eq/year
# [codecarbon INFO @ 02:01:18] Energy consumed for RAM : 0.012373 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 02:01:18] Energy consumed for all CPUs : 0.110677 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 02:01:18] 0.123049 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:01:33] Energy consumed for RAM : 0.012393 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 02:01:33] Energy consumed for all CPUs : 0.110853 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 02:01:33] 0.123246 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:01:48] Energy consumed for RAM : 0.012412 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 02:01:48] Energy consumed for all CPUs : 0.111030 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 02:01:48] 0.123443 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:02:03] Energy consumed for RAM : 0.012432 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 02:02:03] Energy consumed for all CPUs : 0.111208 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 02:02:03] 0.123640 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:02:18] Energy consumed for RAM : 0.012452 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 02:02:18] Energy consumed for all CPUs : 0.111385 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 02:02:18] 0.123837 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:02:33] Energy consumed for RAM : 0.012472 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 02:02:33] Energy consumed for all CPUs : 0.111562 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 02:02:33] 0.124033 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:02:48] Energy consumed for RAM : 0.012491 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 02:02:48] Energy consumed for all CPUs : 0.111739 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 02:02:48] 0.124230 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:03:03] Energy consumed for RAM : 0.012511 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 02:03:03] Energy consumed for all CPUs : 0.111916 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 02:03:03] 0.124427 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:03:03] 0.003510 g.CO2eq/s mean an estimation of 110.70481020757452 kg.CO2eq/year
# [codecarbon INFO @ 02:03:18] Energy consumed for RAM : 0.012531 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 02:03:18] Energy consumed for all CPUs : 0.112093 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 02:03:18] 0.124624 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:03:33] Energy consumed for RAM : 0.012551 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 02:03:33] Energy consumed for all CPUs : 0.112270 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 02:03:33] 0.124821 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:03:48] Energy consumed for RAM : 0.012571 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 02:03:48] Energy consumed for all CPUs : 0.112447 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 02:03:48] 0.125018 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:04:03] Energy consumed for RAM : 0.012590 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 02:04:03] Energy consumed for all CPUs : 0.112624 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 02:04:03] 0.125215 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:04:18] Energy consumed for RAM : 0.012610 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 02:04:18] Energy consumed for all CPUs : 0.112802 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 02:04:18] 0.125412 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:04:33] Energy consumed for RAM : 0.012630 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 02:04:33] Energy consumed for all CPUs : 0.112979 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 02:04:33] 0.125609 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:04:48] Energy consumed for RAM : 0.012650 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 02:04:48] Energy consumed for all CPUs : 0.113156 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 02:04:48] 0.125806 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:05:03] Energy consumed for RAM : 0.012670 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 02:05:03] Energy consumed for all CPUs : 0.113333 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 02:05:03] 0.126003 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:05:03] 0.003510 g.CO2eq/s mean an estimation of 110.6988460281751 kg.CO2eq/year
# [codecarbon INFO @ 02:05:18] Energy consumed for RAM : 0.012690 kWh. RAM Power : 4.7530388832092285 W
# [codecarbon INFO @ 02:05:18] Energy consumed for all CPUs : 0.113510 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 02:05:18] 0.126200 kWh of electricity used since the beginning.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in _determine_best_metric(self, metrics, trial)
#    3150             try:
# -> 3151                 metric_value = metrics[metric_to_check]
#    3152             except KeyError as exc:
#
# KeyError: 'eval_accuracy'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-31fbb15874ed> in <cell line: 0>()
#       6 )
#       7
# ----> 8 trainer.train()
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2162                 hf_hub_utils.enable_progress_bars()
#    2163         else:
# -> 2164             return inner_training_loop(
#    2165                 args=args,
#    2166                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2616
#    2617             self.control = self.callback_handler.on_epoch_end(args, self.state, self.control)
# -> 2618             self._maybe_log_save_evaluate(tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval, start_time)
#    2619
#    2620             if DebugOption.TPU_METRICS_DEBUG in self.args.debug:
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in _maybe_log_save_evaluate(self, tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval, start_time)
#    3048         if self.control.should_evaluate:
#    3049             metrics = self._evaluate(trial, ignore_keys_for_eval)
# -> 3050             is_new_best_metric = self._determine_best_metric(metrics=metrics, trial=trial)
#    3051
#    3052             if self.args.save_strategy == SaveStrategy.BEST:
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in _determine_best_metric(self, metrics, trial)
#    3151                 metric_value = metrics[metric_to_check]
#    3152             except KeyError as exc:
# -> 3153                 raise KeyError(
#    3154                     f"The `metric_for_best_model` training argument is set to '{metric_to_check}', which is not found in the evaluation metrics. "
#    3155                     f"The available evaluation metrics are: {list(metrics.keys())}. Consider changing the `metric_for_best_model` via the TrainingArguments."
#
# KeyError: "The `metric_for_best_model` training argument is set to 'eval_accuracy', which is not found in the evaluation metrics. The available evaluation metrics are: []. Consider changing the `metric_for_best_model` via the TrainingArguments."

# %%
results = trainer.evaluate()
print(f"Evaluation results: {results}")
# Out:
#     <div>
#
#       <progress value='15' max='15' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [15/15 15:10]
#     </div>
# Evaluation results: {'eval_runtime': 987.8977, 'eval_samples_per_second': 0.957, 'eval_steps_per_second': 0.015, 'epoch': 3.0}

# %%
def evaluate_model(model, dataset, tokenizer):
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for batch in dataset:
            inputs = tokenizer(batch['quote'], padding=True, truncation=True, return_tensors="pt")
            inputs = {k: v.to(model.device) for k, v in inputs.items()}
            labels = torch.tensor(batch['label']).to(model.device)

            outputs = model(**inputs)
            preds = torch.argmax(outputs.logits, dim=1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    accuracy = (np.array(all_preds) == np.array(all_labels)).mean()
    precision, recall, f1, _ = precision_recall_fscore_support(all_labels, all_preds, average='weighted')
    conf_matrix = confusion_matrix(all_labels, all_preds)
    auc_roc = roc_auc_score(all_labels, all_preds, average='weighted', multi_class='ovr')

    print(f'Test Accuracy: {accuracy:.2f}')
    print(f'Precision: {precision:.2f}')
    print(f'Recall: {recall:.2f}')
    print(f'F1 Score: {f1:.2f}')
    print(f'AUC-ROC: {auc_roc:.2f}')
    print('Confusion Matrix:')
    print(conf_matrix)

    return accuracy, precision, recall, f1, auc_roc, conf_matrix

# Use the function
metrics = evaluate_model(model, dataset['test'], tokenizer)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-1da4ed542d3a> in <cell line: 0>()
#      32
#      33 # Use the function
# ---> 34 metrics = evaluate_model(model, dataset['test'], tokenizer)
#
# <ipython-input-34-1da4ed542d3a> in evaluate_model(model, dataset, tokenizer)
#      14
#      15             all_preds.extend(preds.cpu().numpy())
# ---> 16             all_labels.extend(labels.cpu().numpy())
#      17
#      18     accuracy = (np.array(all_preds) == np.array(all_labels)).mean()
#
# TypeError: iteration over a 0-d array
